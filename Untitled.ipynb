# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# %%
data = np.loadtxt('319bec_avg.txt')

# %%
def add_noise(data):
    x,y = data.shape
    add = np.random.randn(x,y)/20
    return data + add

# %%
while(1 > 0):
    time.sleep(10)
    np.savetxt('newimage.txt',add_noise(data))

# %%
plt.imshow(add_noise(data))

# %%
import matplotlib.animation as anim

def plot_cont(fun, xmax):
    y = []
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)

    def update(i):
        yi = fun()
        y.append(yi)
        x = range(len(y))
        ax.clear()
        ax.plot(x, y)
        print(i, ': ', yi)

    a = anim.FuncAnimation(fig, update, frames=xmax, repeat=False)
    plt.show()

# %%
plt.hist(data[0:20,0:20].ravel())
np.std(data[0:20,0:20].ravel())
plt.figure()
plt.plot(data.ravel())

# %%
x = [i*7.04 for i in range(data.shape[1])]

plt.scatter(x,np.sum(data, axis =0), s = .7)

# %%
plt.imshow(data)
plt.imshow(data[100:150,50:150])
